# %%
import os
def sed(pattern, replacement, fin, fout):
    finMem=open(fin)
    foutMem=open(fout,'w+')
    for line in finMem:
        if pattern in line:
            print('pattern found')
            newLine=line.replace(pattern, replacement)
            foutMem.write(line)
